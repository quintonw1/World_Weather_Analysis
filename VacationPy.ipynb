# %%
# %matplotlib inline

# %%
# Import the Dependicies
import pandas as pd
import requests
import gmaps 
# import the API key 
from config import g_key

# %%
# Import excel file "cities.csv"

city_data_df = pd.read_csv("Data/cities.csv")
city_data_df.head()
# Out:
#    City_ID                 City Country                 Date    Lat     Lng  \
# 0        0              Kahului      US  2020-05-27 20:31:16  20.89 -156.47
# 1        1              Mataura      NZ  2020-05-27 20:32:19 -46.19  168.86
# 2        2                Pevek      RU  2020-05-27 20:32:19  69.70  170.31
# 3        3  Gardone Val Trompia      IT  2020-05-27 20:32:20  45.69   10.19
# 4        4           Bredasdorp      ZA  2020-05-27 20:32:20 -34.53   20.04
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     87.80        48          40        8.05
# 1     37.76        86           0        1.88
# 2     37.96        76         100       15.86
# 3     69.80        49           5        2.24
# 4     55.40        58           0        6.93

# %%
#Checking data types in DataFrame 
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key. 
gmaps.configure(api_key=g_key)

# %%
## 1. Assign the locations to an array of latitude and longitude pairs.
#locations = [latitude, longitude]
## 2. Assign the weights variable to some values.
#temperatures = # an array of equal length of the locations array.
## 3. Assign the figure variable to the gmaps.figure() attribute.
#fig = gmaps.figure()
## 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
#heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)

## 5. Add the heatmap layer.
#fig.add_layer(heatmap_layer)
## 6. Call the figure to plot the data.
#fig

# %%
# Heatmap of Temperature 
# Get the latitude and longtitude. 
locations = city_data_df[["Lat", "Lng"]]
# Get Maximum temperature 
max_temp = city_data_df["Max Temp"]
# Assign the figure variable 
fig = gmaps.figure(center=(30.0,31.0), zoom_level = 1.25)
# Assign the heatmap_layer variable and add it to the locations
heatmap_layer = gmaps.heatmap_layer(locations, weights = [max(temp,0) for temp in max_temp],
                                   dissipating = False, max_intensity = 300, point_radius =4)
#Add the heatmap layer
fig.add_layer(heatmap_layer)
# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity 
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30,31), zoom_level = 1.25)
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, dissipating = False, max_intensity = 300, point_radius = 4)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent Cloudiness 
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30,31), zoom_level = 1.25)
heat_layer = gmaps.heatmap_layer(locations, weights = clouds, dissipating = False, max_intensity = 300, point_radius = 4)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent Wind Speed 
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30,31), zoom_level = 1.25)
heat_layer = gmaps.heatmap_layer(locations, weights = wind, dissipating = False, max_intensity = 300, point_radius = 4)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value. 

min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 77
# What is the maximum temperature you would like for your trip? 86

# %%
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                      (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 20       20     Grand Forks      US  2020-05-27 20:28:45  47.93  -97.03
# 23       23       Jamestown      US  2020-05-27 20:31:18  42.10  -79.24
# 24       24           Kapaa      US  2020-05-27 20:32:26  22.08 -159.32
# 33       33            Hilo      US  2020-05-27 20:30:06  19.73 -155.09
# 37       37       Namatanai      PG  2020-05-27 20:32:31  -3.67  152.43
# 38       38       Boa Vista      BR  2020-05-27 20:32:31   2.82  -60.67
# 43       43     Port-Gentil      GA  2020-05-27 20:32:32  -0.72    8.78
# 45       45         Tautira      PF  2020-05-27 20:32:33 -17.73 -149.15
# 46       46  Cabo San Lucas      MX  2020-05-27 20:30:12  22.89 -109.91
# 47       47        Phangnga      TH  2020-05-27 20:32:34   8.45   98.53
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 20     80.60        26          75       21.92
# 23     82.00        47           1       12.75
# 24     80.60        65          20       11.41
# 33     82.40        58          75        3.36
# 37     80.47        80         100        6.35
# 38     86.00        62          75        3.36
# 43     80.60        88          40       12.75
# 45     86.00        70          20        6.93
# 46     84.20        44           5       10.29
# 47     80.60        88          20        2.15

# %%
# Check if there are any null values 
preferred_cities_df.count()
# Out:
# City_ID       145
# City          145
# Country       145
# Date          145
# Lat           145
# Lng           145
# Max Temp      145
# Humidity      145
# Cloudiness    145
# Wind Speed    145
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat",
                               "Lng"]].copy()
hotel_df = hotel_df.reset_index()

hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#    index            City Country  Max Temp    Lat     Lng Hotel Name
# 0     20     Grand Forks      US     80.60  47.93  -97.03
# 1     23       Jamestown      US     82.00  42.10  -79.24
# 2     24           Kapaa      US     80.60  22.08 -159.32
# 3     33            Hilo      US     82.40  19.73 -155.09
# 4     37       Namatanai      PG     80.47  -3.67  152.43
# 5     38       Boa Vista      BR     86.00   2.82  -60.67
# 6     43     Port-Gentil      GA     80.60  -0.72    8.78
# 7     45         Tautira      PF     86.00 -17.73 -149.15
# 8     46  Cabo San Lucas      MX     84.20  22.89 -109.91
# 9     47        Phangnga      TH     80.60   8.45   98.53

# %%
# Set Parameters to search for a hotel.
params = {"radius":5000,
         "type": "lodging",
         "key": g_key,
         "location": ""}

# Iterate through the DataFrame. 
for index, row in hotel_df.iterrows():
    
    # Get the latitude and longtitude
    lat = row["Lat"]
    lng = row["Lng"]
    city = row["City"]
    # add the latitude and longitude to location key for the params dict
    params["location"] = f"{lat},{lng}"
    
    # Use base url to search for hotels:
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params = params).json()
    try: 
        # Grab the first hotel from the results and store the name. 
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    
    except (IndexError):
        print(f"Hotel not found in {city}.... skipping")
# Out:
# Hotel not found in Badajoz.... skipping
# Hotel not found in Maraa.... skipping
# Hotel not found in Mabaruma.... skipping
# Hotel not found in Thinadhoo.... skipping
# Hotel not found in Wattegama.... skipping
# Hotel not found in Puro.... skipping
# Hotel not found in Tessalit.... skipping
# Hotel not found in Marzuq.... skipping
# Hotel not found in Mitu.... skipping
# Hotel not found in Kieta.... skipping

# %%
hotel_df.head(10)
# Out:
#    index            City Country  Max Temp    Lat     Lng  \
# 0     20     Grand Forks      US     80.60  47.93  -97.03
# 1     23       Jamestown      US     82.00  42.10  -79.24
# 2     24           Kapaa      US     80.60  22.08 -159.32
# 3     33            Hilo      US     82.40  19.73 -155.09
# 4     37       Namatanai      PG     80.47  -3.67  152.43
# 5     38       Boa Vista      BR     86.00   2.82  -60.67
# 6     43     Port-Gentil      GA     80.60  -0.72    8.78
# 7     45         Tautira      PF     86.00 -17.73 -149.15
# 8     46  Cabo San Lucas      MX     84.20  22.89 -109.91
# 9     47        Phangnga      TH     80.60   8.45   98.53
#
#                                Hotel Name
# 0           TownHouse Hotel - Grand Forks
# 1          Hampton Inn & Suites Jamestown
# 2  Sheraton Kauai Resort at Coconut Beach
# 3                     Hilo Hawaiian Hotel
# 4                         Namatanai Hotel
# 5                      Aipana Plaza Hotel
# 6                      Fengshui Residence
# 7                            Pension Oaoa
# 8                  Hotel Tesoro Los Cabos
# 9                       Muang Thong Hotel

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Add a heatmap of temperature for the vacation spots.

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center = (30.0,31.0), zoom_level = 1.25)
heat_layer = (gmaps.heatmap_layer(locations, weights = max_temp, dissipating=False,
                                 max_intensity=300, point_radius =4))
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info) 
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
